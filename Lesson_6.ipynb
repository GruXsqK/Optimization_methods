# %% [markdown]
# __Для выполнения работ $P_1$, $P_2$, $P_3$ сельскохозяйственное предприятие может приобрести тракторы марок $А$ и $B$ стоимостью соответственно $c_1$ и $c_2$ ден. ед. каждый. С использованием новой техники необходимо выполнить не менее $b_1$ условных единиц работы $P_1$ не менее $b_2$ условных единиц работы $P_2$ и не менее $b_3$ условных единиц работы $P_3$. За рассматриваемый промежуток времени с использованием трактора марки $A$ можно выполнить $a_{11}$ условных единиц работы $P_1$, $a_{21}$ условных единиц работы $P_2$ или $a_{31}$ условных единиц работы $P_3$; с использованием трактора марки $B$ – $a_{12}$ условных единиц работы $P_1$, $a_{22}$ условных единиц работы $P_2$ или $a_{23}$ условных единиц работы $P_3$.__
#
# __Требуется:__
#
# __Составить экономико-математическую модель, позволяющую найти такой вариант приобретения тракторов той или другой марки, при котором будут выполнены все необходимые работы, а затраты на новую технику будут минимальны;
# Пользуясь методом ветвей и границ, найти оптимальный вариант приобретения тракторов.__
#
# __$b_1$ = 20, $b_2$ = 190, $b_3$ = 88, $a_{11}$ = 4, $a_{21}$ = 19, $a_{31}$=4, $a_{12}$ = 1, $a_{22}$ = 15, $a_{32}$ = 15, $c_1$= 3, $c_2$ = 5__

# %% [markdown]
# Целевая функция, выражающая стоимость закупки: <br>
# $f=A * c_1 + B * c_2 \rightarrow min$, где $A$ и $B$ - количества тракторов соответствующих марок <br>
# При этом $A, B \geq 0$ <br>
#
# $\left\{ \begin{matrix}
# A*a_{11} + B*a_{12} \leq b_1\\
# A*a_{21} + B*a_{22} \leq b_2\\
# A*a_{31} + B*a_{32} \leq b_3
# \end{matrix} \right.$

# %% [markdown]
# Подставим известные значения: <br>
#
# $\left\{ \begin{matrix}
# 4A + B \leq 20\\
# 19A + 15B \leq 190\\
# 4A + 15B \leq 88
# \end{matrix} \right.$
#
# $\left\{ \begin{matrix}
# 4A \leq 20 - B\\
# 19A + 15B \leq 190\\
# 20 - B + 15B \leq 88
# \end{matrix} \right.$
#
# Из первого неравенства $\Rightarrow 4A \leq 20 - B$, подставим его в третье: <br>
# $14B \leq 68 \Rightarrow B \leq 4,857$
#
# Рассмотрим 2 ветви:<br>
# 1) $B \leq 4 \Rightarrow A \leq 4$ <br>
# $4*4 + 15*4 \leq 88 \Rightarrow 86 \leq 88$ - третье неравенство выполняется<br>
# 2) $B \geq 5 \Rightarrow A \leq \frac{15}{4}$<br>
# $4*\frac{15}{4} + 15*5 \leq 88 \Rightarrow 90 \leq 88$ третье неравенство не выполняется <br>
# Вторую ветвь отбрасываем.<br>
#
# Рассмотрим следующие 2 ветви: <br>
# 1) $B \geq 3 \Rightarrow A \leq 10,75$ - не выполняется первое неравенство<br>
# 2) $B \leq 4 \Rightarrow A \leq 4$ <br>
#
# Расчитаем ЦФ: <br>
# $f=3*4+5*4=32$

# %% [markdown]
# __Оптимальный вариант приобретения тракторов: 4 трактора марки $A$ и 4 трактора марки $B$.__
